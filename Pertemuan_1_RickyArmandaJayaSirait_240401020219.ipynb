# %% [markdown]
# <a href="https://colab.research.google.com/github/rickyajs/Data-Science-2026/blob/main/Pertemuan_1_RickyArmandaJayaSirait_240401020219.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Ricky Armanda Jaya Sirait
# NIM   : 240401020219
# Prodi

# %%
#=======================================================
# PERTEMUAN 1 : Notebook Pertama Data Sciene
#=======================================================

# SEL 1 : Output Sederhana
print ("Hello, Data Science !")
print ("Selamat Datang di mata kuliah Pengantar Data Science!")

# SEKL 2 : Variabel dan tipe data dasar
nama         = "Ricky Armanda Jaya Sirait"      # String
angkatan     = 2024                             # Integer
ipk          = 4.00                             # Float
aktif        = True                             # Boolean

print (f"Nama     : {nama}")
print (f"Angkatan : {angkatan}")
print (f"Ipk      : {ipk}")
print (f"Aktif    : {aktif}")

# SEL 3 : List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
print ("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate (tools, 1) :
    print(f" {i}. {tool}")

# SEL 4 : Fungsi Sederhana
def perkenalan (nama, prodi, angkatan) :
    """Fungsi Untuk Menampilkan Perkenalan Mahasiswa."""
    return f"Hai ! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Ricky Armanda Jaya Sirait", "Informatika", 2024)
print (hasil)
# Out:
# Hello, Data Science !
# Selamat Datang di mata kuliah Pengantar Data Science!
# Nama     : Ricky Armanda Jaya Sirait
# Angkatan : 2024
# Ipk      : 4.0
# Aktif    : True
#
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. Github
# Hai ! Saya Ricky Armanda Jaya Sirait dari Informatika, angkatan 2024.
